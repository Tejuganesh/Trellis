# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejuganesh/Trellis/blob/main/TRELLIS_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install aria2 -qqy

#!pip install torch==2.5.0+cu124 torchvision==0.20.0+cu124 torchaudio==2.5.0+cu124 torchtext==0.18.0 torchdata==0.8.0 --extra-index-url https://download.pytorch.org/whl/cu124
# !pip install xformers==0.0.28.post2
#!pip install https://github.com/Dao-AILab/flash-attention/releases/download/v2.6.3/flash_attn-2.6.3+cu123torch2.3cxx11abiFALSE-cp310-cp310-linux_x86_64.whl

# %cd /content
# !git clone --recursive https://github.com/Microsoft/TRELLIS
# %cd /content/TRELLIS

# !pip install easydict rembg onnxruntime onnxruntime-gpu numpy==2.0.0 plyfile huggingface-hub safetensors
#!pip install git+https://github.com/NVlabs/nvdiffrast trimesh xatlas pyvista pymeshfix igraph spconv-cu120
# !pip install opencv-python imageio imageio-ffmpeg ffmpeg-python av
#!pip install https://github.com/camenduru/wheels/releases/download/3090/kaolin-0.17.0-cp310-cp310-linux_x86_64.whl
#!pip install https://github.com/camenduru/wheels/releases/download/3090/diso-0.1.4-cp310-cp310-linux_x86_64.whl
#!pip install https://github.com/camenduru/wheels/releases/download/3090/utils3d-0.0.2-py3-none-any.whl
#!pip install https://huggingface.co/spaces/JeffreyXiang/TRELLIS/resolve/main/wheels/nvdiffrast-0.3.3-cp310-cp310-linux_x86_64.whl
#!pip install https://huggingface.co/spaces/JeffreyXiang/TRELLIS/resolve/main/wheels/diff_gaussian_rasterization-0.0.0-cp310-cp310-linux_x86_64.whl

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/pipeline.json -d /content/model -o pipeline.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_dec_gs_swin8_B_64l8gs32_fp16.json -d /content/model/ckpts -o slat_dec_gs_swin8_B_64l8gs32_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_dec_gs_swin8_B_64l8gs32_fp16.safetensors -d /content/model/ckpts -o slat_dec_gs_swin8_B_64l8gs32_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_dec_mesh_swin8_B_64l8m256c_fp16.json -d /content/model/ckpts -o slat_dec_mesh_swin8_B_64l8m256c_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_dec_mesh_swin8_B_64l8m256c_fp16.safetensors -d /content/model/ckpts -o slat_dec_mesh_swin8_B_64l8m256c_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_dec_rf_swin8_B_64l8r16_fp16.json -d /content/model/ckpts -o slat_dec_rf_swin8_B_64l8r16_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_dec_rf_swin8_B_64l8r16_fp16.safetensors -d /content/model/ckpts -o slat_dec_rf_swin8_B_64l8r16_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_enc_swin8_B_64l8_fp16.json -d /content/model/ckpts -o slat_enc_swin8_B_64l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_enc_swin8_B_64l8_fp16.safetensors -d /content/model/ckpts -o slat_enc_swin8_B_64l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_flow_img_dit_L_64l8p2_fp16.json -d /content/model/ckpts -o slat_flow_img_dit_L_64l8p2_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_flow_img_dit_L_64l8p2_fp16.safetensors -d /content/model/ckpts -o slat_flow_img_dit_L_64l8p2_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/ss_dec_conv3d_16l8_fp16.json -d /content/model/ckpts -o ss_dec_conv3d_16l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/ss_dec_conv3d_16l8_fp16.safetensors -d /content/model/ckpts -o ss_dec_conv3d_16l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/ss_enc_conv3d_16l8_fp16.json -d /content/model/ckpts -o ss_enc_conv3d_16l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/ss_enc_conv3d_16l8_fp16.safetensors -d /content/model/ckpts -o ss_enc_conv3d_16l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/ss_flow_img_dit_L_16l8_fp16.json -d /content/model/ckpts -o ss_flow_img_dit_L_16l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/ss_flow_img_dit_L_16l8_fp16.safetensors -d /content/model/ckpts -o ss_flow_img_dit_L_16l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://github.com/facebookresearch/dinov2/zipball/main -d /root/.cache/torch/hub -o main.zip
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_reg4_pretrain.pth -d /root/.cache/torch/hub/checkpoints -o dinov2_vitl14_reg4_pretrain.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx -d /root/.u2net -o u2net.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://github.com/facebookresearch/dinov2/zipball/main -d /root/.cache/torch/hub -o main.zip

# %cd /content/TRELLIS

import numpy as np
import torch
import imageio
from typing import *
from PIL import Image
from easydict import EasyDict as edict
from trellis.pipelines import TrellisImageTo3DPipeline
from trellis.representations import Gaussian, MeshExtractResult
from trellis.utils import render_utils, postprocessing_utils

MAX_SEED = np.iinfo(np.int32).max
TMP_DIR = "/content"

def preprocess_image(image_path: str) -> Tuple[str, Image.Image]:
    trial_id = "trellis-tost"
    image = Image.open(image_path).convert("RGBA")
    processed_image = pipeline.preprocess_image(image)
    processed_image.save(f"{TMP_DIR}/{trial_id}.png")
    return trial_id, processed_image

def pack_state(gs: Gaussian, mesh: MeshExtractResult, trial_id: str) -> dict:
    return {
        'gaussian': {
            **gs.init_params,
            '_xyz': gs._xyz.cpu().numpy(),
            '_features_dc': gs._features_dc.cpu().numpy(),
            '_scaling': gs._scaling.cpu().numpy(),
            '_rotation': gs._rotation.cpu().numpy(),
            '_opacity': gs._opacity.cpu().numpy(),
        },
        'mesh': {
            'vertices': mesh.vertices.cpu().numpy(),
            'faces': mesh.faces.cpu().numpy(),
        },
        'trial_id': trial_id,
    }

def unpack_state(state: dict) -> Tuple[Gaussian, edict, str]:
    gs = Gaussian(
        aabb=state['gaussian']['aabb'],
        sh_degree=state['gaussian']['sh_degree'],
        mininum_kernel_size=state['gaussian']['mininum_kernel_size'],
        scaling_bias=state['gaussian']['scaling_bias'],
        opacity_bias=state['gaussian']['opacity_bias'],
        scaling_activation=state['gaussian']['scaling_activation'],
    )
    gs._xyz = torch.tensor(state['gaussian']['_xyz'], device='cuda')
    gs._features_dc = torch.tensor(state['gaussian']['_features_dc'], device='cuda')
    gs._scaling = torch.tensor(state['gaussian']['_scaling'], device='cuda')
    gs._rotation = torch.tensor(state['gaussian']['_rotation'], device='cuda')
    gs._opacity = torch.tensor(state['gaussian']['_opacity'], device='cuda')

    mesh = edict(
        vertices=torch.tensor(state['mesh']['vertices'], device='cuda'),
        faces=torch.tensor(state['mesh']['faces'], device='cuda'),
    )

    return gs, mesh, state['trial_id']

def image_to_3d(image_path: str, seed: int = 0, randomize_seed: bool = True,
                ss_guidance_strength: float = 7.5, ss_sampling_steps: int = 12,
                slat_guidance_strength: float = 3.0, slat_sampling_steps: int = 12) -> Tuple[dict, str]:
    trial_id, _ = preprocess_image(image_path)
    if randomize_seed:
        seed = np.random.randint(0, MAX_SEED)

    outputs = pipeline.run(
        Image.open(f"{TMP_DIR}/{trial_id}.png"),
        seed=seed,
        formats=["gaussian", "mesh"],
        preprocess_image=False,
        sparse_structure_sampler_params={
            "steps": ss_sampling_steps,
            "cfg_strength": ss_guidance_strength,
        },
        slat_sampler_params={
            "steps": slat_sampling_steps,
            "cfg_strength": slat_guidance_strength,
        },
    )

    video = render_utils.render_video(outputs['gaussian'][0], num_frames=120)['color']
    video_geo = render_utils.render_video(outputs['mesh'][0], num_frames=120)['normal']
    video = [np.concatenate([video[i], video_geo[i]], axis=1) for i in range(len(video))]
    trial_id = "trellis-tost"
    video_path = f"{TMP_DIR}/{trial_id}.mp4"
    imageio.mimsave(video_path, video, fps=15)

    state = pack_state(outputs['gaussian'][0], outputs['mesh'][0], str(trial_id))
    return state, video_path

def extract_glb(state: dict, mesh_simplify: float = 0.95, texture_size: int = 1024) -> str:
    gs, mesh, trial_id = unpack_state(state)
    glb = postprocessing_utils.to_glb(gs, mesh, simplify=mesh_simplify, texture_size=texture_size, verbose=False)
    glb_path = f"{TMP_DIR}/{trial_id}.glb"
    glb.export(glb_path)
    return glb_path

with torch.inference_mode():
    pipeline = TrellisImageTo3DPipeline.from_pretrained("/content/model")
    pipeline.cuda()
# Out:
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch==2.5.0+cu124 in /usr/local/lib/python3.12/dist-packages (2.5.0+cu124)
# Requirement already satisfied: torchvision==0.20.0+cu124 in /usr/local/lib/python3.12/dist-packages (0.20.0+cu124)
# Requirement already satisfied: torchaudio==2.5.0+cu124 in /usr/local/lib/python3.12/dist-packages (2.5.0+cu124)
# Requirement already satisfied: torchtext==0.18.0 in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: torchdata==0.8.0 in /usr/local/lib/python3.12/dist-packages (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0+cu124) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.20.0+cu124) (2.0.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.20.0+cu124) (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torchtext==0.18.0) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torchtext==0.18.0) (2.32.4)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.12/dist-packages (from torchdata==0.8.0) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.5.0+cu124) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.5.0+cu124) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torchtext==0.18.0) (2026.2.25)
# Requirement already satisfied: xformers==0.0.28.post2 in /usr/local/lib/python3.12/dist-packages (0.0.28.post2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xformers==0.0.28.post2) (2.0.0)
# Requirement already satisfied: torch==2.5.0 in /usr/local/lib/python3.12/dist-packages (from xformers==0.0.28.post2) (2.5.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0->xformers==0.0.28.post2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.5.0->xformers==0.0.28.post2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.5.0->xformers==0.0.28.post2) (3.0.3)
# ERROR: flash_attn-2.6.3+cu123torch2.3cxx11abiFALSE-cp310-cp310-linux_x86_64.whl is not a supported wheel on this platform.
# /content
# fatal: destination path 'TRELLIS' already exists and is not an empty directory.
# /content/TRELLIS
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (1.13)
# Requirement already satisfied: rembg in /usr/local/lib/python3.12/dist-packages (2.0.69)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (1.24.3)
# Requirement already satisfied: onnxruntime-gpu in /usr/local/lib/python3.12/dist-packages (1.24.3)
# Requirement already satisfied: numpy==2.0.0 in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (0.7.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from rembg) (4.26.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from rembg) (4.13.0.92)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from rembg) (11.3.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from rembg) (1.9.0)
# Requirement already satisfied: pymatting in /usr/local/lib/python3.12/dist-packages (from rembg) (1.1.15)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from rembg) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from rembg) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rembg) (4.67.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (6.0.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->rembg) (4.9.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch->rembg) (2.32.4)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from pymatting->rembg) (0.60.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg) (2026.2.24)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub) (0.0.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->pymatting->rembg) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->rembg) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->rembg) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub) (0.1.2)
# Collecting git+https://github.com/NVlabs/nvdiffrast
#   Cloning https://github.com/NVlabs/nvdiffrast to /tmp/pip-req-build-o786pxb0
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast /tmp/pip-req-build-o786pxb0
#   Resolved https://github.com/NVlabs/nvdiffrast to commit 253ac4fcea7de5f396371124af597e6cc957bfae
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.2)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.12/dist-packages (0.2.0)
# Requirement already satisfied: av in /usr/local/lib/python3.12/dist-packages (16.1.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python) (1.0.0)
# ERROR: kaolin-0.17.0-cp310-cp310-linux_x86_64.whl is not a supported wheel on this platform.
# ERROR: diso-0.1.4-cp310-cp310-linux_x86_64.whl is not a supported wheel on this platform.
# Collecting utils3d==0.0.2
#   Downloading https://github.com/camenduru/wheels/releases/download/3090/utils3d-0.0.2-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: moderngl in /usr/local/lib/python3.12/dist-packages (from utils3d==0.0.2) (5.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from utils3d==0.0.2) (2.0.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.12/dist-packages (from utils3d==0.0.2) (1.1.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from utils3d==0.0.2) (1.16.3)
# Requirement already satisfied: glcontext>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from moderngl->utils3d==0.0.2) (3.0.0)
# ERROR: nvdiffrast-0.3.3-cp310-cp310-linux_x86_64.whl is not a supported wheel on this platform.
# ERROR: diff_gaussian_rasterization-0.0.0-cp310-cp310-linux_x86_64.whl is not a supported wheel on this platform.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 196443|OK  |       0B/s|/content/model/pipeline.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c4a964|OK  |       0B/s|/content/model/ckpts/slat_dec_gs_swin8_B_64l8gs32_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a4764d|OK  |       0B/s|/content/model/ckpts/slat_dec_gs_swin8_B_64l8gs32_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# aa52fd|OK  |       0B/s|/content/model/ckpts/slat_dec_mesh_swin8_B_64l8m256c_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 65ef5c|OK  |       0B/s|/content/model/ckpts/slat_dec_mesh_swin8_B_64l8m256c_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5da36b|OK  |       0B/s|/content/model/ckpts/slat_dec_rf_swin8_B_64l8r16_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f041ad|OK  |       0B/s|/content/model/ckpts/slat_dec_rf_swin8_B_64l8r16_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c8f681|OK  |       0B/s|/content/model/ckpts/slat_enc_swin8_B_64l8_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# de4b76|OK  |       0B/s|/content/model/ckpts/slat_enc_swin8_B_64l8_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 639ef1|OK  |       0B/s|/content/model/ckpts/slat_flow_img_dit_L_64l8p2_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d5568c|OK  |       0B/s|/content/model/ckpts/slat_flow_img_dit_L_64l8p2_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5b5eba|OK  |       0B/s|/content/model/ckpts/ss_dec_conv3d_16l8_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 42b6b8|OK  |       0B/s|/content/model/ckpts/ss_dec_conv3d_16l8_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4dcc1a|OK  |       0B/s|/content/model/ckpts/ss_enc_conv3d_16l8_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fff762|OK  |       0B/s|/content/model/ckpts/ss_enc_conv3d_16l8_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ba4804|OK  |       0B/s|/content/model/ckpts/ss_flow_img_dit_L_16l8_fp16.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 70abad|OK  |       0B/s|/content/model/ckpts/ss_flow_img_dit_L_16l8_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7a1850|OK  |       0B/s|/root/.cache/torch/hub/main.zip
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7eec0e|OK  |       0B/s|/root/.cache/torch/hub/checkpoints/dinov2_vitl14_reg4_pretrain.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9225f8|OK  |       0B/s|/root/.u2net/u2net.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 192446|OK  |       0B/s|/root/.cache/torch/hub/main.zip
#
# Status Legend:
# (OK):download completed.
# /content/TRELLIS
# [SPARSE] Backend: spconv, Attention: flash_attn
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5743/309031313.py in <cell line: 0>()
#      48 from PIL import Image
#      49 from easydict import EasyDict as edict
# ---> 50 from trellis.pipelines import TrellisImageTo3DPipeline
#      51 from trellis.representations import Gaussian, MeshExtractResult
#      52 from trellis.utils import render_utils, postprocessing_utils
#
# /content/TRELLIS/trellis/__init__.py in <module>
#       3 from . import pipelines
#       4 from . import renderers
# ----> 5 from . import representations
#       6 from . import utils
#
# /content/TRELLIS/trellis/representations/__init__.py in <module>
#       2 from .octree import DfsOctree as Octree
#       3 from .gaussian import Gaussian
# ----> 4 from .mesh import MeshExtractResult
#
# /content/TRELLIS/trellis/representations/mesh/__init__.py in <module>
# ----> 1 from .cube2mesh import SparseFeatures2Mesh, MeshExtractResult
#
# /content/TRELLIS/trellis/representations/mesh/cube2mesh.py in <module>
#       3 from easydict import EasyDict as edict
#       4 from .utils_cube import *
# ----> 5 from .flexicubes.flexicubes import FlexiCubes
#       6
#       7
#
# /content/TRELLIS/trellis/representations/mesh/flexicubes/flexicubes.py in <module>
#      15 import torch
#      16 from .tables import *
# ---> 17 from kaolin.utils.testing import check_tensor
#      18
#      19 __all__ = [
#
# ModuleNotFoundError: No module named 'kaolin'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 1. Clean up any failed attempts
# !rm -rf kaolin
# !pip cache purge

# 2. Set environment flags so the compiler doesn't panic
import os
os.environ['IGNORE_TORCH_VER'] = '1'

# 3. Install dependencies first
# !pip install --no-build-isolation cython numpy==1.26.4

# 4. Install Kaolin directly from the stable 2026-ready source
# This takes about 5-8 minutes. If it "hangs," it's just compiling!
# !pip install git+https://github.com/NVIDIAGameWorks/kaolin.git --no-build-isolation
# Out:
# Files removed: 6
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (3.0.12)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Collecting git+https://github.com/NVIDIAGameWorks/kaolin.git
#   Cloning https://github.com/NVIDIAGameWorks/kaolin.git to /tmp/pip-req-build-dnjkb1zz
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIAGameWorks/kaolin.git /tmp/pip-req-build-dnjkb1zz
#   Resolved https://github.com/NVIDIAGameWorks/kaolin.git to commit d4c2695f63b5b49e4c37b9a3bb6701df3545eea5
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (7.34.0)
# Collecting ipycanvas (from kaolin==0.18.0)
#   Downloading ipycanvas-0.14.3-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (2.0.4)
# Requirement already satisfied: jupyter_client<8 in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (7.4.9)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (3.1.3)
# Requirement already satisfied: tornado in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (6.5.1)
# Collecting comm>=0.1.3 (from kaolin==0.18.0)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting usd-core (from kaolin==0.18.0)
#   Downloading usd_core-26.3-cp312-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (1.26.4)
# Collecting pybind11 (from kaolin==0.18.0)
#   Downloading pybind11-3.0.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (11.3.0)
# Requirement already satisfied: tqdm>=4.51.0 in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (4.67.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from kaolin==0.18.0) (1.16.3)
# Collecting pygltflib (from kaolin==0.18.0)
#   Downloading pygltflib-1.16.5-py3-none-any.whl.metadata (33 kB)
# Collecting warp-lang (from kaolin==0.18.0)
#   Downloading warp_lang-1.12.0-py3-none-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter_client<8->kaolin==0.18.0) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter_client<8->kaolin==0.18.0) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from jupyter_client<8->kaolin==0.18.0) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter_client<8->kaolin==0.18.0) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.12/dist-packages (from jupyter_client<8->kaolin==0.18.0) (26.2.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyter_client<8->kaolin==0.18.0) (5.7.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->kaolin==0.18.0) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask->kaolin==0.18.0) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->kaolin==0.18.0) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask->kaolin==0.18.0) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->kaolin==0.18.0) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->kaolin==0.18.0) (3.1.6)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.12/dist-packages (from ipycanvas->kaolin==0.18.0) (7.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (75.2.0)
# Collecting jedi>=0.16 (from ipython->kaolin==0.18.0)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->kaolin==0.18.0) (4.9.0)
# Collecting dataclasses-json>=0.0.25 (from pygltflib->kaolin==0.18.0)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated (from pygltflib->kaolin==0.18.0)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib->kaolin==0.18.0)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib->kaolin==0.18.0)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->kaolin==0.18.0) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter_client<8->kaolin==0.18.0) (4.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->kaolin==0.18.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->kaolin==0.18.0) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter_client<8->kaolin==0.18.0) (1.17.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->pygltflib->kaolin==0.18.0) (2.1.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.8.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (5.9.5)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->kaolin==0.18.0)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->kaolin==0.18.0) (4.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (6.5.7)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.3.3)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (3.11)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.18.0) (2025.3)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading ipycanvas-0.14.3-py2.py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 13.3 MB/s eta 0:00:00
# Downloading pybind11-3.0.2-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 23.9 MB/s eta 0:00:00
# Downloading pygltflib-1.16.5-py3-none-any.whl (27 kB)
# Downloading usd_core-26.3-cp312-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (28.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.5/28.5 MB 78.0 MB/s eta 0:00:00
# Downloading warp_lang-1.12.0-py3-none-manylinux_2_28_x86_64.whl (136.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 MB 7.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.5 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: kaolin
#   Building wheel for kaolin (setup.py) ... done
#   Created wheel for kaolin: filename=kaolin-0.18.0-cp312-cp312-linux_x86_64.whl size=13942538 sha256=df4cc3ac628c77e6b4189a09d5f9e9b3365c8166517a68a6c36e032af0f42a3c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q_c7eehv/wheels/25/fe/81/5122a45e676165f39f5a573c3c1552017789966d7a743f9f4c
# Successfully built kaolin
# Installing collected packages: warp-lang, usd-core, pybind11, mypy-extensions, marshmallow, jedi, deprecated, comm, typing-inspect, dataclasses-json, pygltflib, ipycanvas, kaolin
# Successfully installed comm-0.2.3 dataclasses-json-0.6.7 deprecated-1.3.1 ipycanvas-0.14.3 jedi-0.19.2 kaolin-0.18.0 marshmallow-3.26.2 mypy-extensions-1.1.0 pybind11-3.0.2 pygltflib-1.16.5 typing-inspect-0.9.0 usd-core-26.3 warp-lang-1.12.0

# %%
input_image = "/content/TRELLIS/T.png"
seed = 0
randomize_seed = True
ss_guidance_strength = 7.5
ss_sampling_steps = 12
slat_guidance_strength = 3.0
slat_sampling_steps = 12
mesh_simplify = 0.95
texture_size = 1024

state, video_path = image_to_3d(image_path=input_image,
                                seed=seed,
                                randomize_seed=randomize_seed,
                                ss_guidance_strength=ss_guidance_strength,
                                ss_sampling_steps=ss_sampling_steps,
                                slat_guidance_strength=slat_guidance_strength,
                                slat_sampling_steps=slat_sampling_steps)
glb_path = extract_glb(state=state, mesh_simplify=mesh_simplify, texture_size=texture_size)
